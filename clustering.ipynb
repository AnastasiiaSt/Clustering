# %% [markdown]
# Each task that is proposed to be completed as part of the homework has a declared "price" in points. The maximum possible amount is 10 points, and together with the bonus assignment - 12 points. It is not necessary to complete all the tasks, only a part can be done. Most of the points expect you to write working Python code; sometimes you will need to write comments - for example, to compare several approaches to solve the same problem. Also you can add more cells for your convenience if you need.

# %% [markdown]
# This homework focuses on clustering. We will work with images of handwritten digits, learn how to cluster them using two different methods (hierarchical clustering and the 𝐾-means algorithm), evaluate the quality of the partition and choose the optimal number of clusters, as well as visualize intermediate results.

# %% [markdown]
# ## 1. Loading data
# The data we will be working with is available in the scikit-learn library (`sklearn` module) in the `datasets` submodule via the `load_digits` function. The data contains 1,797 observations, each of which is 8×8 pixel image of a handwritten digit from 0 to 9. This is about the same amount of each digit (about 180).
#
# For convenience, every image expands to a 64 (8×8) row, so entire numpy array is 1797×64. The color intensity in each pixel is encoded with an integer from 0 to 16.
#
# In addition to images, their labels are also known. In this task, we will assume that the labels (as well as their amount) are unknown and try to group the data in such a way that the resulting clusters 'better match' the original ones. Possible options for determining the 'better match' are presented later.

# %% [markdown]
# **(0.25 points)** Load the images into `X` variable, and their labels into `y` variable.

# %%
# Load the dataset from sklearn

from sklearn.datasets import load_digits

data = load_digits()

X = data.data
y = data.target

# %%
assert X.shape == (1797, 64)
assert y.shape == (1797,)

# %% [markdown]
# **(0.5 points)** Visualize the first 10 images.
#
# - Arrange images on a grid rather than in a row. You may need the `subplot` and `imshow` functions from the `pyplot` module in the `matplotlib` library.
# - You will also need to reshape the images to 8×8.
# - Remove ticks and labels from both axes. The `xticks` and `yticks` functions or the `tick_params` function from `pyplot` can help you with this.
# - Make the output good sized with the `figure` function from `pyplot`.

# %%
# Import required libraries

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import numpy as np
import pandas as pd
from sklearn.exceptions import NotFittedError
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, v_measure_score, silhouette_samples
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from matplotlib import cm
from scipy.cluster.hierarchy import dendrogram
from numpy.random import RandomState
import random
import time
from cycler import cycler
np.random.seed = 42

# %%
# Create function for numbers visualization

def visual_numbers(data, title = ''):
    fig, axes = plt.subplots(2, 5, figsize = (16, 6))
    plt.suptitle(title, fontsize = 14)

    for i in range(0, 10):
        row = 0
        column = i
        if i >= 5:
            row = 1
            column = column - 5
        axes[row, column].imshow(data[i, :, :])
        axes[row, column].xaxis.set_visible(False)
        axes[row, column].yaxis.set_visible(False)

# %%
# Reshape the data for image rendering

X_graph = X.reshape((-1, 8, 8))
title = 'Examples of digits from the dataset'

visual_numbers(X_graph, title = title)

# %% [markdown]
# ## 2. Clustering and quality evaluation

# %% [markdown]
# **(2 points)** Implement the the KMeans algorithm. Use objective function $L = \sum_{i=1}^{n}|x_{i}-Z_{A(x_{i})}|^{2}$, where $Z_{A(x_{i})}$ is the center of the cluster corresponding to $x_{i}$ object.

# %%
class CustomKMeans:
    def __init__(self, n_clusters=2, max_iter=30, n_init=10, random_state=42):
        '''K-Means clustering.
        
        Args:
            n_clusters: int, default=2
                The number of clusters to be formed is also 
                the number of centroids to generate. 
            max_iter: int, default=300
                Maximum number of iterations of the k-means algorithm for a
                single run.
            n_init: int, default=10
                Number of time the k-means algorithm will be run with different
                centroid seeds. The final results will be the best output of
                n_init consecutive runs in terms of objective function.
            random_state: int, default=42
                Random state.
        '''
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.max_iter = max_iter
        self.random_state = RandomState(seed=random_state)
        self.cluster_centers = None
        self.initial_cluster_centers = None
        self.objective = None
        self.objective_list = []
        self.cluster_centers_list = []
        
    def calculate_distances_to_centroids(self, X, cluster_centers):
        """
        Returns (n, c) matrix where the element at position (i, j) 
        is the distance from i-th object to j-th centroid."""
        # <your code>
        nearest_clusters = np.empty((X.shape[0], self.n_clusters))
        for i in range(X.shape[0]):
            nearest_clusters[i, :] = np.sqrt(np.sum((cluster_centers - X[i, :])**2, axis = 1))
        return nearest_clusters
    
    def update_centroids(self, X, nearest_clusters):
        """
        Returns numpy array of shape (n_clusters, n_features) - 
        new clusters that are found by averaging objects belonging 
        to the corresponding cluster."""
        # <your code>       
        nearest = np.argmin(nearest_clusters, axis = 1)
        cluster_centers = np.empty((self.n_clusters, X.shape[1]))
        for c in range(self.n_clusters):
            if (X[c == nearest, :]).shape[0] == 0:
                cluster_centers[c, :] = [rand.choice(X[:, i], replace = False) for i in range(X.shape[1])]          
            else:
                cluster_centers[c, :] = np.mean(X[c == nearest, :], axis = 0) 
        return cluster_centers
    
    def objective_cost(self, X, cluster_centers):
        objective = np.empty((X.shape[0]))
        for i in range(X.shape[0]):
            objective[i] = np.min(np.sqrt(np.sum((cluster_centers - X[i, :])**2, axis = 1)), axis = 0)**2
        return np.sum(objective)
        
    def fit(self, X):
        """Fit the model.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
        """
        assert X.shape[0] >= self.n_clusters
        # <your code>     
        rand = self.random_state
        for iterat in range(self.n_init):
            cluster_centers = np.empty((self.n_clusters, X.shape[1]))
            for c in range(self.n_clusters):
                cluster_centers[c, :] = [rand.choice(X[:, i], replace = False) for i in range(X.shape[1])]
            self.initial_cluster_centers = cluster_centers
            for i in range(self.max_iter):        
                nearest_clusters = self.calculate_distances_to_centroids(X, cluster_centers)
                cluster_centers = self.update_centroids(X, nearest_clusters)             
                self.cluster_centers = cluster_centers
            self.cluster_centers_list.append(cluster_centers)
            self.objective = self.objective_cost(X, self.cluster_centers)
            self.objective_list.append(self.objective)
        self.cluster_centers = self.cluster_centers_list[np.argmin(self.objective_list)]
        self.objective = np.min(self.objective_list)
        return self
            
    
    def predict(self, X):
        """Predict classes.
        
        Args:
            X: numpy array of shape (n_samples, n_features)
        Returns:
            y: numpy array of shape (n_samples,)
                Vector containing predicted cluster labels.
        """
        if hasattr(self, 'cluster_centers'):
            # <your code>
            nearest_clusters = self.calculate_distances_to_centroids(X, self.cluster_centers)
            return np.argmin(nearest_clusters, axis = 1)
        else: 
            raise NotFittedError("CustomKMeans instance is not fitted yet")

# %%
# Check the correctness of the CustomKMeans class

cust_model = CustomKMeans(n_init=20)
cust_model.fit(X)
cust_pred = cust_model.predict(X)

model = KMeans(n_clusters = 2, init = 'random', max_iter=30, n_init=20, random_state=42)
model.fit(X)
sk_pred = model.predict(X)

accuracy = 100 * accuracy_score(cust_pred, sk_pred)

print('Custom KMeans class works {}% same as sklearn KMeans class.'.format(accuracy))
print('Objective of Custom KMeans is {}, objective of sklearn KMeans is {}.'\
      .format(round(cust_model.objective), round(model.inertia_)))
# Out:
# Custom KMeans class works 100.0% same as sklearn KMeans class.
# Objective of Custom KMeans is 1914620, objective of sklearn KMeans is 1914620.

# %% [markdown]
# **(1 points)** Get the `X` array partition into 10 clusters. Visualize the centers of clusters.
# - We will assume that the center of the cluster is average value of all observations belonging to the cluster.
# - The cluster centers should have the same shape as our observations (64). So you have to average the points across the rows.

# %%
# Build model with 10 clusters

cust_model = CustomKMeans(n_clusters = 10, random_state = 42, n_init = 30)
cust_model.fit(X)

custom_kmeans_labels = cust_model.predict(X)
assert custom_kmeans_labels.shape == (1797,)

# %%
# Visualize the centers of clusters for some feautures 

s = 6

rand = np.random.RandomState(42)

feature1 = rand.randint(low = 0, high = X.shape[1], size = s)
feature2 = rand.randint(low = 0, high = X.shape[1], size = s)

fig, axes = plt.subplots(2, s // 2, figsize = (16, 10))
fig.suptitle('Result of clustering for some features', fontsize = 14)
for i in range(s):
    row = 0
    column = i
    if i >= s / 2:
        row = 1
        column = column - s // 2
    axes[row, column].scatter(X[:, feature1[i]], X[:, feature2[i]], c = custom_kmeans_labels, alpha = 0.3, s = 15, 
                              cmap = 'ocean')
    axes[row, column].scatter(cust_model.cluster_centers[:, feature1[i]], cust_model.cluster_centers[:, feature2[i]], 
                              c = np.unique(custom_kmeans_labels), cmap = 'ocean', marker = 'x', s = 60)

# %%
# Vusualize cluster centers as images

X_graph = cust_model.cluster_centers.reshape((-1, 8, 8))
title = 'Centers of clusters'

visual_numbers(X_graph, title = title)

# %% [markdown]
# **(0.5 points)** Experiment with `max_iter` and `n_init` parameters. Look at the range of values of the objective function, it's best values, at what parameters and how often they are achieved.

# %%
# Create function for hyperparameters tuning

def hyperparameters_tuning(max_iters, n_inits):
    objectives = []
    if isinstance(max_iters, int):
        max_iters = [max_iters]
        evaluated = n_inits
        axisx = 'Number of initialization'
    if isinstance(n_inits, int):
        n_inits = [n_inits]
        evaluated = max_iters
        axisx = 'Number of iteration'
    for max_iter in max_iters:
        for n_init in n_inits:
            model = KMeans(max_iter = max_iter, n_init = n_init, random_state = 42, n_clusters = 10)
            model.fit(X)
            objectives.append(model.inertia_)
    plt.figure(figsize = (16, 6))
    plt.plot(evaluated, objectives, color = '#3f6480')
    y = np.mean(objectives)
    x = evaluated[np.argmin(objectives + evaluated * np.min(objectives) * 0.00001)]
    plt.axvline(x, linestyle = '--', color = 'black', linewidth = 1)
    plt.text(x = x - 0.3, y = y, s = 'Hyperparameter showing best objective', rotation = 90)
    plt.title('{} versus model objective'.format(axisx))
    plt.xlabel(axisx)
    plt.ylabel('Model objective')
    plt.xticks(list(evaluated).append(int(x)))
    plt.grid(visible = True, axis = 'x', which = 'both', alpha = 0.5)
    plt.grid(visible = True, axis = 'y', which = 'major', alpha = 0.5)
    plt.show()
    return int(x)

# %%
# Create plot for number of iteration impact on objective 

max_iters = np.arange(1, 30)
n_inits = 1

max_iter = hyperparameters_tuning(max_iters = max_iters, n_inits = n_inits)
print('Optimum number of iterations for the model is {}.'.format(max_iter))
# Out:
# Optimum number of iterations for the model is 13.

# %% [markdown]
# Model objective significantly drops while number of iterations is below 13, with number of iteration above 13 it remains the same, so the cluster centers don't move anymore.

# %%
# Create plot for number of initialization impact on objective 

max_iters = max_iter
n_inits = np.arange(1, 30)

max_init = hyperparameters_tuning(max_iters = max_iters, n_inits = n_inits)
print('Optimum number of initialization for the model is {}.'.format(max_init))
# Out:
# Optimum number of initialization for the model is 4.

# %% [markdown]
# Increasing number of runs of the model improves its objective even more. It helps to find optimum initialization for cluster centers.

# %% [markdown]
# Now we will use two popular algorithms: hierarchical clustering and $K$-means clustering. These and other algorithms are available in the `scikit-learn` module in the `cluster` submodule. Hierarchical clustering is called `AgglomerativeClustering`, and the $K$-means method is called `KMeans`.
#
# **(0.5 points)** Use each of the two methods: hierarchical clustering and KMeans. Get the `X` array partition into 10 clusters.
#
# - Note that `AgglomerativeClustering` does not have a `predict` method, so you can either use the `fit_predict` method or use the `fit` method and then look at the `labels_` attribute of the class instance.
# - Kmeans performs multiple runs (default 10) with random centers and then returns the best partition in terms of average distance within the clusters. You can increase the number of runs to improve the quality of predictions in the `i_init` parameter.

# %%
kmeans_model = KMeans(n_clusters = 10, n_init = 20)
hierarchical_model = AgglomerativeClustering(n_clusters = 10, compute_distances= True)

kmeans_model.fit(X)
hierarchical_model.fit(X)

hierarchical_labels = hierarchical_model.labels_
kmeans_labels = kmeans_model.predict(X)

# %%
assert hierarchical_labels.shape == (1797,)
assert kmeans_labels.shape == (1797,)

# %% [markdown]
# **(0.5 points)** Visualize the centers of clusters obtained by both methods.

# %%
visual_numbers(kmeans_model.cluster_centers_.reshape((-1, 8, 8)), title = 'Center of clusters obtained by KMeans clustering')

# %%
hierarchical_centers = np.empty((10, X.shape[1]))
for i in range(10):
    hierarchical_centers[i, :] = np.mean(X[hierarchical_labels == i, :], axis = 0)

# %%
visual_numbers(hierarchical_centers.reshape((-1, 8, 8)), title = 'Center of clusters obtained by Hierarchical clustering')

# %% [markdown]
# In a situation where the true number of classes is unknown, we can select it by maximazing some metric.
#
# When we can set some distance function between our observations, we can consider the `silhouette` distance as a function of measuring the quality of the clustering. Let's show how it is calculated:

# %% [markdown]
# Let $X$ – set of observations, $M \subset X$ – one of the clusters obtained as a result of clustering process, $\rho$ – some metric on $X$. Let's choose one observation $x \in M$. Denote $a(x)$ as the average distance from $x$ to  $x'$ points from the same cluster:
# $$
# a(x) = \frac{1}{|M| - 1} \sum_{x' \in M,\, x' \ne x} \rho(x,\, x')
# $$
#
# Denote $b(x)$ as minimun of average distances from $x$ to $x''$ from some other cluster $N$:
# $$
# b(x) = \min_{N \ne M} \frac{1}{|N|} \sum_{x'' \in N} \rho(x,\, x'')
# $$
#
# The silhouette is difference between a(x) and b(x), normalized to $[-1, \, 1]$ and averaged over all observations:
# $$
# \frac{1}{|X|} \sum_{x \in X} \frac{b(x) - a(x)}{\max(a(x),\, b(x))}
# $$
#
# The implementation of this metric in the `scikit-learn` is the `silhouette_score` function from the `metrics` submidule.

# %% [markdown]
# **(0.75 point)** For each $K$ between 2 and 20 inclusive, partition of the array $X$ into $K$ clusters using both methods. Calculate the silhouette score and visualize it for both methods on the same plot ($K$ on the $x$ axis and silhouette score on the $y$ axis). Sign the axes and make a legend.

# %%
ks = np.arange(2, 21)
kmeans_s_scores = []
hierarchical_s_scores = []

for k in ks:
    kmeans_model = KMeans(n_clusters = k, n_init = 20)
    kmeans_model.fit(X)
    kmeans_pred = kmeans_model.predict(X)
    kmeans_s_scores.append(silhouette_score(X, kmeans_pred, random_state = 42))
    
    hierarchical_model = AgglomerativeClustering(n_clusters = k)
    hierarchical_model.fit(X)
    hierarchical_s_scores.append(silhouette_score(X, hierarchical_model.labels_, random_state = 42))

# %%
plt.figure(figsize = (16, 6))
plt.plot(ks, kmeans_s_scores, color = '#3f6480')
plt.plot(ks, hierarchical_s_scores, color = '#733d42')
plt.legend(['KMeans model', 'Hierarchical model'])
plt.title('Relation between number of clusters and Silhouette score')
plt.xticks(ks)
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
plt.grid(visible = True, axis = 'x', which = 'both', alpha = 0.5)
plt.grid(visible = True, axis = 'y', which = 'major', alpha = 0.5)
plt.show()

# %%
colors = ['#104b6b', '#3f6480', '#637e96','#869aac', '#a9b6c2', '#ccd3d9', '#f1f1f1', '#d8cacb', '#bfa5a6', 
                  '#a68183', '#8d5e62', '#733d42', '#591b25', '#104b6b', '#3f6480', '#637e96','#869aac']

def silhouette_diagram(X, ks = [10, 11, 12], model = 'KMeans'):
    fig, axes = plt.subplots(1, len(ks), figsize = (16, 8))
    plt.subplots_adjust(wspace = 0.2)
    fig.suptitle('Silhouette diagram for {} model'.format(model))
    for i, k in zip(range(len(ks)), ks):
        
        if model == 'KMeans':
            model = KMeans(n_clusters = k, n_init = 20)
            model.fit(X)
            pred = model.predict(X)    
        elif model == 'Hierarchical':
            model = AgglomerativeClustering(n_clusters = k)
            model.fit(X)
            pred = model.labels_

        average_score = silhouette_score(X, pred)
        samples_scores = silhouette_samples(X, pred)
        
        y_l = 10    
        
        for j in range(k):
            jth_cluster_values = samples_scores[kmeans_pred ==j]
            jth_cluster_values.sort()
            
            cluster_size = jth_cluster_values.shape[0]
            y_u = y_l + cluster_size
            
            axes[i].fill_betweenx(np.arange(y_l, y_u), 0, jth_cluster_values, edgecolor = 'black', facecolor = colors[j])
            axes[i].text(-0.05, y_l + 0.5 * cluster_size, str(j))
            y_l = y_u + 10

        axes[i].set_title('{} clusters'.format(k))
        axes[i].set_xlabel('Silhouette coefficient value')
        axes[i].set_ylabel('Cluster')
        axes[i].axvline(x = average_score, color = 'black', linewidth = 0.5, linestyle = 'dashed')  
        axes[i].set_yticks([])

# %%
silhouette_diagram(X, ks = [9, 10, 17], model = 'Hierarchical')

# %%
silhouette_diagram(X, ks = [9, 10, 15], model = 'KMeans')

# %% [markdown]
# When we know the true clustering labels, the clustering result can be compared to them using measures such as `homogeneity`, `completeness` and their harmonic mean - $V$-score. The definitions of these quantities are rather bulky and are based on the [entropy of the probability distribution](https://ru.wikipedia.org/wiki/Информационная_энтропия). Details are given in [this article](http://aclweb.org/anthology/D/D07/D07-1043.pdf). In practice, it's enough to know that `homogeneity`, `completeness` and $V$-score are in the range from 0 and 1, and the more, the better.
#
# Since we know what digit each image is (`y` array), we can compare the clustering results to it using the measures listed above.

# %% [markdown]
# **(0.5 points)** Repeat the previous task using $V$-measure instead of silhouette.

# %%
ks = np.arange(2, 21)
kmeans_v_scores = []
hierarchical_v_scores = []

for k in ks:
    kmeans_model = KMeans(n_clusters = k, n_init = 20)
    kmeans_model.fit(X)
    kmeans_pred = kmeans_model.predict(X)
    kmeans_v_scores.append(v_measure_score(y, kmeans_pred))
    
    hierarchical_model = AgglomerativeClustering(n_clusters = k)
    hierarchical_model.fit(X)
    hierarchical_v_scores.append(v_measure_score(y, hierarchical_model.labels_))

# %%
plt.figure(figsize = (16, 6))
plt.plot(ks, kmeans_v_scores, color = '#3f6480')
plt.plot(ks, hierarchical_v_scores, color = '#733d42')
plt.legend(['KMeans model', 'Hierarchical model'])
plt.title('Relation between number of clusters V-measure score')
plt.xticks(ks)
plt.xlabel('Number of clusters')
plt.ylabel('V-measure score')
plt.grid(visible = True, axis = 'x', which = 'both', alpha = 0.5)
plt.grid(visible = True, axis = 'y', which = 'major', alpha = 0.5)
plt.show()

# %% [markdown]
# ## 3. Feature space dimensionality reduction
#
# In some cases, especially when there are a large number of features, when not all of them are informative, and some of them are correlated, it can be useful to reduce the dimension of the feature space. This mean that instead of $d$ original features, we will go to $d'\ll d$ new ones. And if earlier our data were presented in the form of an $n×d$ matrix, then it will presented as a $n×d'$.
#
# There are two popular dimensionality reduction approaches:
# - select new features from existing features;
# - extract the new features by transforming old ones, for example, by making $d'$ different linear combinations of columns of an $n×d$ matrix.
#
# One widely used dimensionality reduction technique is the Singular Value Decomposition (SVD). This method allows you to construct any number $d'\leq d$ of new features in such a way that they are the most informative (in some sense).
#
# The `scikit-learn` module has several implementations of singular value decomposition. We will use the `TruncatedSVD` class from the `decomposition` submodule.
#
# **Note:** The singular value decomposition of the matrix $M$ is usually written as $M=U \Sigma V^{*}$. `TruncatedSVD`, in turn, returns only the $d'$ first columns of the matrix $U$.

# %% [markdown]
# **(0.75 point)** Perform a singular value decomposition of the $X$ matrix, leaving 2, 5, 10, 20 features. In each case, perform hierarchical clustering and $K$-Means clustering (take the number of clusters equal to 10). Calculate the silhouette and $V$-score and compare them to corresponding values obtained from the original data.
#
# **Note**: It is not valid to compare the silhouette calculated with different metrics. Even if we use the same metric function when calculating the distance between points in the data, after applying dimensionality reduction or other data transformations, we will (not always) get different silhouette scores. Therefore, after training the clustering algorithm, to compare the result of clustering, you need to calculate the silhouette on the original data.

# %%
n_components = [2, 5, 10, 20]
km_s_scores = []
km_v_scores = []
h_s_scores = []
h_v_scores = []

for n in n_components:
    svd = TruncatedSVD(n_components = n)
    svd.fit(X)
    reduced_X = np.dot(X, svd.components_.T)
    model_kmeans = KMeans(n_clusters = 10)
    model_kmeans.fit(reduced_X)
    pred_kmeans = model_kmeans.predict(reduced_X)
    km_s_scores.append(silhouette_score(X, pred_kmeans))
    km_v_scores.append(v_measure_score(y, pred_kmeans))
    model_hierar = AgglomerativeClustering(n_clusters = 10)
    model_hierar.fit(reduced_X)
    h_s_scores.append(silhouette_score(X, model_hierar.labels_))
    h_v_scores.append(v_measure_score(y, model_hierar.labels_))

# %%
plt.figure(figsize = (16, 6))
plt.plot(n_components, km_s_scores, color = '#3f6480')
plt.plot(n_components, h_s_scores, color = '#733d42')
plt.plot(n_components, [kmeans_s_scores[8]] * len(n_components), color = '#5e6b89', linewidth = 1, linestyle = '--')
plt.plot(n_components, [hierarchical_s_scores[8]] * len(n_components), color = '#a16669', linewidth = 1, linestyle = '--')
plt.legend(['KMeans on reduced dataset', 'Hierarchical ckustering on reduced dataset', 
            'KMeans on original dataset', 'Hierarchical ckustering on original dataset'])
plt.title('Relation between number of features in dataset and Silhouette score')
plt.xticks(ks)
plt.xlabel('Number of features')
plt.ylabel('Silhouette score')
plt.grid(visible = True, axis = 'x', which = 'both', alpha = 0.5)
plt.grid(visible = True, axis = 'y', which = 'major', alpha = 0.5)
plt.show()

# %%
plt.figure(figsize = (16, 6))
plt.plot(n_components, km_v_scores, color = '#3f6480')
plt.plot(n_components, h_v_scores, color = '#733d42')
plt.plot(n_components, [kmeans_v_scores[8]] * len(n_components), color = '#5e6b89', linewidth = 1, linestyle = '--')
plt.plot(n_components, [hierarchical_v_scores[8]] * len(n_components), color = '#a16669', linewidth = 1, linestyle = '--')
plt.legend(['KMeans on reduced dataset', 'Hierarchical ckustering on reduced dataset',
            'KMeans on original dataset', 'Hierarchical ckustering on original dataset'])
plt.title('Relation between number of features in dataset and V-measure score')
plt.xticks(ks)
plt.xlabel('Number of features')
plt.ylabel('V-measure score')
plt.grid(visible = True, axis = 'x', which = 'both', alpha = 0.5)
plt.grid(visible = True, axis = 'y', which = 'major', alpha = 0.5)
plt.show()

# %% [markdown]
# According to the graphs, dimensionality reduction does not improve the model performance. However the model with reduced data reaches the same performance as with original data in much less time. So, dimensionality reduction boosts the learning process.

# %% [markdown]
# Another popular dimensionality reduction approach that is useful for working with images is t-distributed stochastic neighbor embeddings, abbreviated `tSNE`. Unlike singular value decomposition, this it is non-linear transformation. It's main idea is to map points from a space of dimension `d` to another space of dimension 2 or 3 in such a way that the distances between points are mostly preserved. Mathematical details can be found, for example, [here](https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding).
#
# The implementation of `tSNE` in the `scikit-learn` library is the `TSNE` class in the `manifold` submodule.
#
# **Note:** In recent years [UMAP](https://github.com/lmcinnes/umap) is often used istead of `tSNE`. It is a faster algorithm with similar properties. We don't ask you to use `UMAP` because it requires you to install another dependency, the `umap-learn` library. Those who wish can perform the following task using `UMAP`.

# %% [markdown]
# **(0.5 points)** Perform a tSNE-transform of the `X` matrix, leaving 2 features. Visualize the obtained data in the form of a scatter plot form: the first feature on the horizontal axis, and the second one the vertical axis. Color the points according to the digits they belong to.
#
# - The `c` parameter in the plt.scatter function is responsible for the color of the points. Pass the true labels to it.

# %%
X_embedded = TSNE(n_components = 2).fit_transform(X)

# %%
plt.figure(figsize = (16, 8))
plt.title('Dimensionality reduction using tSNE')
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c = y, cmap = 'twilight_shifted', edgecolor = 'black')
plt.show()

# %% [markdown]
# **(0.5 points)** From the data transformed using the tSNE, perform hierarchical clustering and $K$-means clustering (take the number of clusters equal to 10). Calculate the silhouette and the $V$-score and compare them to corresponding values obtained from the original data.

# %%
hierar_model = AgglomerativeClustering(n_clusters = 10)
hierar_model.fit(X_embedded)
score_on_reduced_data = v_measure_score(y, hierar_model.labels_)
original_score = hierarchical_v_scores[8]
print('V measure score on data with reduced dimensions is {}.'.format(round(score_on_reduced_data, 2)))
print('V measure score on original data is {}.'.format(round(original_score, 2)))
print('Performance improvement is {}%.'.format(round(abs(100 * (original_score - score_on_reduced_data) / original_score))))
# Out:
# V measure score on data with reduced dimensions is 0.88.
# V measure score on original data is 0.87.
# Performance improvement is 1%.

# %% [markdown]
# Dimensionality reduction using tSNE improves Hierarchical Clustering performance.

# %% [markdown]
# **(0.25 points)** Choose the best partition (in terms of silhouette or $V$-score) and visualize the centers of clusters with images. Did you managed to make each digit correspond to one center of the cluster?

# %%
hierar_labels = hierar_model.labels_

hierar_centers = np.empty((10, X.shape[1]))
for i in range(10):
    hierar_centers[i, :] = np.mean(X[hierar_labels == i, :], axis = 0)

visual_numbers(hierar_centers.reshape((-1, 8, 8)), 
               title = 'Center of clusters obtained by Hierarchical clustering on reduced data')

# %% [markdown]
# According to the images, each cluster center corresponds to one unique labels of the dataset. All numbers in the images are distinguishable.

# %% [markdown]
# ## 4. Results and bonus part

# %% [markdown]
# Write in free form what conclusions you made after completing this assignment. Answer the following questions:
#
# **(0.5 points)** Which algorithm gives more meaningful results - hierarchical clustering or $K$- means clustering. Does it depend on the algorithm settings or on the quality evaluation method?

# %% [markdown]
# When evaluating model using V measure score, hierarchical clustering shows better results, whereas, based on Silhouette score KMeans clustering performs better. So, determination which algorithm is more meaningful depends on the quality evaluation method. Also, it should be considered that hyperparameters of KMeans clustering model influence its performance.

# %% [markdown]
# **(0.5 points)** Imagine the situation where after hierarchical clustering, you need to cluster new data in the same way without retraining the model. Suggest a method how you will do it and how you will measure the quality of clustering of new data.

# %% [markdown]
# K-nearest neighbors model can be trained on the initial dataset using labels obtained during Hierarchical clustering. Afterwards, labels for new data can be predicted with the K-nearest neighbors model. Clustering performance on the new data can be evaluated using using Silhouette score.

# %% [markdown]
# **(0.5 points)** Does dimensionality reduction improve clustering results?

# %% [markdown]
# In models impletented in this notebook PCA reduces features dimensions by droping the pixels on images borders and/or combining neighboring pixels, which boosts the learning process. Model trained on features obtained with tSNE shows better performance than model trained on original features. <br>
#
# Dimensionality reduction not necessarily improves clustering results. Moreover, sometimes model performance can slightly decrease due to information loss. However, in general, dimensionality reduction eliminates non-meaninful information in datasets with high number of dimensions, and as a result, considerably speeds up training process.

# %% [markdown]
# **(0.5 points)** How to evaluate the quality of dimensional reduction? Suggest at least 2 options.

# %% [markdown]
# In application, where dimensionality reduction is used as a preprocessing step for further machine learning model, the model performance can be used as a metric for dimensionality reduction evaluations. If model performance doesn't drop with reduced number of features, then no important information was losen and the qualit of dimensonality reduction is sufficient. <br>
#
# Another option to evaluate the quality of dimensionality reduction is to decompress the reduced dataset back to original dataset and calculate reconstruction error between reconstructed and original datasets.

# %% [markdown]
# **(Bonus 2 points)** Load the [MNIST Handwritten Digits](http://yann.lecun.com/exdb/mnist) dataset. You can also do it with `scikit-learn` as explained [here](https://stackoverflow.com/a/60450028). Explore the data and try to cluster it using different approaches. Compare results of these approaches using the silhouette and the $V$-score.

# %%
# Create function to convert input data type into csv

def convert(image_file, label_file, output_file, n):
    f = open(image_file, "rb")
    o = open(output_file, "w")
    l = open(label_file, "rb")

    f.read(16)
    l.read(8)
    images = []

    for i in range(n):
        image = [ord(l.read(1))]
        for j in range(28*28):
            image.append(ord(f.read(1)))
        images.append(image)

    for image in images:
        o.write(",".join(str(pix) for pix in image)+"\n")
    f.close()
    o.close()
    l.close()

convert("train-images.idx3-ubyte", "train-labels.idx1-ubyte", "mnist_train.csv", 60000)
convert("t10k-images.idx3-ubyte", "t10k-labels.idx1-ubyte", "mnist_test.csv", 10000)

# %%
# Import the data

training_data = pd.read_csv('mnist_train.csv')
test_data = pd.read_csv('mnist_test.csv')

# %%
# Divide data into features and labels

y_train = training_data.iloc[:, 0]
X_train = training_data.iloc[:, 1:]

y_test = test_data.iloc[:, 0]
X_test = test_data.iloc[:, 1:]

# %%
# Display the inputs
        
visual_numbers(X_train.values.reshape((-1, 28, 28)), title = 'Samples in MNIST dataset')

# %%
# Check performance on the original data

start = time.time()
kmeans_model = KMeans(n_clusters = 10, max_iter = 30, n_init = 15)
kmeans_model.fit(X_train, y_train)
stop = time.time()

# Prediction evaluation

train_pred = kmeans_model.predict(X_train)
s_score = silhouette_score(X_train, train_pred)
v_score = v_measure_score(y_train, train_pred)

print('V measure score is {} and silhouette score is {} using KMeans model on original training data.'.format(round(v_score, 3),
                round(s_score, 3)))
# Out:
# V measure score is 0.482 and silhouette score is 0.056 using KMeans model on original training data.

# %%
# Create summary table

summary = pd.DataFrame(data = {'KMeans': ['No', round(s_score, 3), round(v_score, 3), round(stop - start)]}, 
                       index = ['Dimensionality Reduction', 'Silhouette score', 'V measure score', 'Training time'])

# %%
# Display the cluster centers
        
visual_numbers(kmeans_model.cluster_centers_.reshape((-1, 28, 28)), title = 'Cluster centers')

# %%
# Create function for detemining number of principal components

def n_components(variance, threshold):
    tot_variance = 0
    for i in range(len(variance)):
        tot_variance = tot_variance + variance[i]
        if tot_variance >= threshold:
            break
    return i

# %%
# Find variance of each principal component

pca = PCA(n_components = X_train.shape[1])
pca.fit(X_train)
variance = pca.explained_variance_ratio_

# %%
# Calculate number of components required to obtain particular variance

start = time.time()
threshold = 0.95
n = n_components(variance, threshold = threshold)

# Reduce dimensionality of the dataset 

pca = PCA(n_components = n)
pca.fit(X_train)
X_train_reduced = np.dot(X_train, pca.components_.T)

# Fit reduced data and evaluate prediction for reduced data

kmeans_model.fit(X_train_reduced, y_train)
stop = time.time()
train_pred = kmeans_model.predict(X_train_reduced)
s_score = silhouette_score(X_train, train_pred)
v_score = v_measure_score(y_train, train_pred)

print('Total number of features is {}.'.format(X_train.shape[1]))
print('Number of features required to obtain {} variance is {}.'.format(threshold, n))
print('V measure score is {} and silhouette score is {} using KMeans model on reduced training data.'.format(round(v_score, 3),
                    round(s_score, 3)))
# Out:
# Total number of features is 784.
# Number of features required to obtain 0.95 variance is 153.
# V measure score is 0.491 and silhouette score is 0.059 using KMeans model on reduced training data.

# %%
add = pd.DataFrame(data = {'KMeans with PCA': ['PCA', round(s_score, 3), round(v_score, 3), round(stop - start)]}, 
                       index = ['Dimensionality Reduction', 'Silhouette score', 'V measure score', 'Training time'])
summary = summary.join(add)
# Out:
#                          KMeans KMeans with PCA
# Dimensionality Reduction     No             PCA
# Silhouette score          0.056           0.059
# V measure score           0.482           0.491
# Training time                29              10

# %%
# Check performance on the original data

start = time.time()
hierar_model = AgglomerativeClustering(n_clusters = 10)
hierar_model.fit(X_train)
stop = time.time()

# Prediction evaluation

s_score = silhouette_score(X_train, hierar_model.labels_)
v_score = v_measure_score(y_train, train_pred)

print('V measure score is {} and silhouette score is {} using Hierarchical clustering on original training data.'\
      .format(round(v_score, 3), round(s_score, 3)))
# Out:
# V measure score is 0.491 and silhouette score is 0.025 using Hierarchical clustering on original training data.

# %%
add = pd.DataFrame(data = {'Hierarchical clustering': ['No', round(s_score, 3), round(v_score, 3), round(stop - start)]}, 
                       index = ['Dimensionality Reduction', 'Silhouette score', 'V measure score', 'Training time'])
summary = summary.join(add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11580/2194959783.py in <module>
# ----> 1 add = pd.DataFrame(data = {'Hierarchical clustering': ['No', round(s_score, 3), round(v_score, 3), round(stop - start)]},
#       2                        index = ['Dimensionality Reduction', 'Silhouette score', 'V measure score', 'Training time'])
#       3 summary = summary.join(add)
#
# NameError: name 'pd' is not defined

# %%
start = time.time()
X_embedded = TSNE(n_components = 2).fit_transform(X_train)
hierar_model = AgglomerativeClustering(n_clusters = 10)
hierar_model.fit(X_embedded)
stop = time.time()

s_score = silhouette_score(X_train, train_pred)
v_score = v_measure_score(y_train, train_pred)

print('V measure score is {} and silhouette score is {} using Hierarchical clustering on reduced training data.'\
      .format(round(v_score, 3), round(s_score, 3)))

# %%
add = pd.DataFrame(data = {'Hierarchical clustering with tSNE': ['tSNE', round(s_score, 3), round(v_score, 3),
            round(stop - start)]}, index = ['Dimensionality Reduction', 'Silhouette score', 'V measure score', 'Training time'])
summary = summary.join(add)

# %%
plt.figure(figsize = (16, 8))
plt.title('Dimensionality reduction using tSNE')
plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c = y_train, cmap = 'twilight_shifted', edgecolor = 'black')
plt.show()

# %%
# Evaluate the best model on test set

pca.fit(X_test)
X_test_reduced = np.dot(X_test, pca.components_.T)
test_pred = kmeans_randomized.predict(X_test_reduced)
v_score = v_measure_score(y_test, test_pred)

print('V measure score on test data is {}.'.format(round(v_score, 3)))
